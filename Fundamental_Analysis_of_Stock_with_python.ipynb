# %%
# !pip install yfinance --quiet

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
yf.Ticker('AAPL').info
# Out:
# {'52WeekChange': 0.09602332,
#  'SandP52WeekChange': -0.06884688,
#  'address1': 'One Apple Park Way',
#  'algorithm': None,
#  'annualHoldingsTurnover': None,
#  'annualReportExpenseRatio': None,
#  'ask': 160.17,
#  'askSize': 1400,
#  'averageDailyVolume10Day': 71774380,
#  'averageVolume': 89379185,
#  'averageVolume10days': 71774380,
#  'beta': 1.19455,
#  'beta3Year': None,
#  'bid': 160.09,
#  'bidSize': 800,
#  'bookValue': 3.61,
#  'category': None,
#  'circulatingSupply': None,
#  'city': 'Cupertino',
#  'coinMarketCapLink': None,
#  'companyOfficers': [],
#  'country': 'United States',
#  'currency': 'USD',
#  'currentPrice': 161.51,
#  'currentRatio': 0.865,
#  'dateShortInterest': 1657843200,
#  'dayHigh': 163.59,
#  'dayLow': 160.89,
#  'debtToEquity': 205.984,
#  'dividendRate': 0.92,
#  'dividendYield': 0.0057,
#  'earningsGrowth': -0.077,
#  'earningsQuarterlyGrowth': -0.106,
#  'ebitda': 129556996096,
#  'ebitdaMargins': 0.3343,
#  'enterpriseToEbitda': 20.71,
# ...

# %%
tickers = ['AAPL', 'MSFT', 'IBM']

# %%
infos = []

for i in tickers:
  infos.append(yf.Ticker(i).info)

# %%
infos
# Out:
# [{'52WeekChange': 0.09602332,
#   'SandP52WeekChange': -0.06884688,
#   'address1': 'One Apple Park Way',
#   'algorithm': None,
#   'annualHoldingsTurnover': None,
#   'annualReportExpenseRatio': None,
#   'ask': 160.17,
#   'askSize': 1400,
#   'averageDailyVolume10Day': 71774380,
#   'averageVolume': 89379185,
#   'averageVolume10days': 71774380,
#   'beta': 1.19455,
#   'beta3Year': None,
#   'bid': 160.09,
#   'bidSize': 800,
#   'bookValue': 3.61,
#   'category': None,
#   'circulatingSupply': None,
#   'city': 'Cupertino',
#   'coinMarketCapLink': None,
#   'companyOfficers': [],
#   'country': 'United States',
#   'currency': 'USD',
#   'currentPrice': 161.51,
#   'currentRatio': 0.865,
#   'dateShortInterest': 1657843200,
#   'dayHigh': 163.59,
#   'dayLow': 160.89,
#   'debtToEquity': 205.984,
#   'dividendRate': 0.92,
#   'dividendYield': 0.0057,
#   'earningsGrowth': -0.077,
#   'earningsQuarterlyGrowth': -0.106,
#   'ebitda': 129556996096,
#   'ebitdaMargins': 0.3343,
# ...

# %%
fundamentals = ['dividendYield', 'marketCap', 'beta', 'forwardPE']

# %%
df = pd.DataFrame(infos)

# %%
df
# Out:
#           zip      sector  fullTimeEmployees  \
# 0       95014  Technology             154000
# 1  98052-6399  Technology             221000
# 2       10504  Technology             282100
#
#                                  longBusinessSummary       city         phone  \
# 0  Apple Inc. designs, manufactures, and markets ...  Cupertino  408 996 1010
# 1  Microsoft Corporation develops, licenses, and ...    Redmond  425 882 8080
# 2  International Business Machines Corporation pr...     Armonk  914 499 1900
#
#   state        country companyOfficers                    website  ...  \
# 0    CA  United States              []      https://www.apple.com  ...
# 1    WA  United States              []  https://www.microsoft.com  ...
# 2    NY  United States              []        https://www.ibm.com  ...
#
#    tradeable dividendYield bidSize  dayHigh  coinMarketCapLink  \
# 0      False        0.0057     800   163.59               None
# ...

# %%
df = df.set_index('symbol')

# %%
df
# Out:
#                zip      sector  fullTimeEmployees  \
# symbol
# AAPL         95014  Technology             154000
# MSFT    98052-6399  Technology             221000
# IBM          10504  Technology             282100
#
#                                       longBusinessSummary       city  \
# symbol
# AAPL    Apple Inc. designs, manufactures, and markets ...  Cupertino
# MSFT    Microsoft Corporation develops, licenses, and ...    Redmond
# IBM     International Business Machines Corporation pr...     Armonk
#
#                phone state        country companyOfficers  \
# symbol
# AAPL    408 996 1010    CA  United States              []
# MSFT    425 882 8080    WA  United States              []
# IBM     914 499 1900    NY  United States              []
#
#                           website  ...  tradeable dividendYield bidSize  \
# symbol                             ...
# AAPL        https://www.apple.com  ...      False        0.0057     800
# ...

# %%
df.columns.isin(fundamentals)
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False,  True, False, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
# ...

# %%
df[df.columns[df.columns.isin(fundamentals)]]
# Out:
#             beta  forwardPE      marketCap  dividendYield
# symbol
# AAPL    1.194550  25.001547  2595594960896         0.0057
# MSFT    0.932311  22.957062  2073368068096         0.0088
# IBM     0.931885  13.047430   118350086144         0.0500

# %%
plt.bar(df.index,df.dividendYield, color=('black', 'orange', 'cyan'))
plt.show()

# %%
plt.bar(df.index,df.forwardPE, color=('black', 'orange', 'cyan'))
plt.show()

# %%
plt.bar(df.index,df.marketCap, color=('black', 'orange', 'cyan'))
plt.show()

# %%
df2 = pd.read_html('https://en.wikipedia.org/wiki/Dow_Jones_Industrial_Average')[1]

# %%
df2
# Out:
#                      Company Exchange Symbol                        Industry  \
# 0                         3M     NYSE    MMM                    Conglomerate
# 1           American Express     NYSE    AXP              Financial services
# 2                      Amgen   NASDAQ   AMGN               Biopharmaceutical
# 3                      Apple   NASDAQ   AAPL          Information technology
# 4                     Boeing     NYSE     BA           Aerospace and defense
# 5                Caterpillar     NYSE    CAT         Construction and Mining
# 6                    Chevron     NYSE    CVX              Petroleum industry
# 7                      Cisco   NASDAQ   CSCO          Information technology
# 8                  Coca-Cola     NYSE     KO                  Drink industry
# 9                     Disney     NYSE    DIS  Broadcasting and entertainment
# 10                       Dow     NYSE    DOW               Chemical industry
# ...

# %%
tickers = df2.Symbol.to_list()

# %%
tickers
# Out:
# ['MMM',
#  'AXP',
#  'AMGN',
#  'AAPL',
#  'BA',
#  'CAT',
#  'CVX',
#  'CSCO',
#  'KO',
#  'DIS',
#  'DOW',
#  'GS',
#  'HD',
#  'HON',
#  'IBM',
#  'INTC',
#  'JNJ',
#  'JPM',
#  'MCD',
#  'MRK',
#  'MSFT',
#  'NKE',
#  'PG',
#  'CRM',
#  'TRV',
#  'UNH',
#  'VZ',
#  'V',
#  'WBA',
#  'WMT']

# %%
infos = []

for i in tickers:
  infos.append(yf.Ticker(i).info)

# %%
df2 = pd.DataFrame(infos)

# %%
df2 = df2.set_index('symbol')

# %%
df2
# Out:
#                zip                  sector  fullTimeEmployees  \
# symbol
# MMM     55144-1000             Industrials              95000
# AXP          10285      Financial Services              64000
# AMGN    91320-1799              Healthcare              24200
# AAPL         95014              Technology             154000
# BA      60606-1596             Industrials             142000
# CAT          60015             Industrials             107700
# CVX     94583-2324                  Energy              42595
# CSCO         95134              Technology              79500
# KO           30313      Consumer Defensive              79000
# DIS          91521  Communication Services             152000
# DOW          48674         Basic Materials              35700
# GS           10282      Financial Services              47000
# HD           30339       Consumer Cyclical             500000
# HON          28202             Industrials              99000
# ...

# %%
df2['dividendYield'].nlargest(5)
# Out:
# symbol
# VZ     0.0531
# DOW    0.0526
# IBM    0.0500
# WBA    0.0439
# MMM    0.0416
# Name: dividendYield, dtype: float64

# %%
plt.figure(figsize=(14,6))
plt.bar(df2['shortName'],df2['dividendYield'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(14,6))
plt.bar(df2['shortName'],df2['marketCap'])
plt.xticks(rotation=90)
plt.show()
