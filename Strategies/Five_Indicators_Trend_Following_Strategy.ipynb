# %%
# !pip install yfinance --quiet
# Out:
#      |████████████████████████████████| 62 kB 1.5 MB/s

# %%
# !pip install talib-binary --quiet
# Out:
#      |████████████████████████████████| 2.4 MB 30.0 MB/s

# %% [markdown]
# # Five Indicators To Build A Trend Following Strategy

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('bmh')

import warnings
warnings.filterwarnings("ignore")

import yfinance as yf
yf.pdr_override()

# %%
# input
symbol = 'TCS.NS'
start = '2007-01-01'
end = '2018-12-31'

# Read data 
data = yf.download(symbol,start,end)

# View Columns
data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2007-01-02  307.350006  314.500000  304.000000  312.125000  234.317184
# 2007-01-03  313.250000  322.000000  309.787506  320.037506  240.257217
# 2007-01-04  321.250000  321.250000  312.524994  314.762512  236.297134
# 2007-01-05  316.250000  317.149994  313.274994  315.750000  237.038528
# 2007-01-08  314.750000  314.750000  303.750000  310.950012  233.435074
#
#              Volume
# Date
# 2007-01-02  1545060
# 2007-01-03  4384972
# 2007-01-04  3970700
# 2007-01-05  2718740
# 2007-01-08  4951892

# %% [markdown]
# ## SMA and EMA

# %%
# Import libraries
import talib as ta

#Simple Moving Average
data['SMA'] = ta.SMA(data['Adj Close'], timeperiod = 20)

# Exponential Moving Average
data['EMA'] = ta.EMA(data['Adj Close'], timeperiod = 20)

# Plot
data[['Adj Close','SMA','EMA']].plot(figsize=(10,5))
plt.show()

# %% [markdown]
# ## Bollinger Bands

# %%
# Bollinger Bands
data['upper_band'], data['middle_band'], data['lower_band'] = ta.BBANDS(data['Adj Close'], timeperiod =20)

# Plot
data[['Adj Close','upper_band','middle_band','lower_band']].plot(figsize=(10,5))
plt.show()

# %% [markdown]
# ## MACD (Moving Average Convergence Divergence)

# %%
# MACD
data['macd'], data['macdsignal'], data['macdhist'] = ta.MACD(data['Adj Close'], fastperiod=12, slowperiod=26, signalperiod=9)
data[['macd','macdsignal']].plot(figsize=(10,5))

plt.show()

# %% [markdown]
# ## RSI (Relative Strength Index)

# %%
# RSI
data['RSI'] = ta.RSI(data['Adj Close'], timeperiod=14)
# Plotting RSI
fig,ax = plt.subplots(figsize=(10,5))
ax.plot(data.index, data.RSI, label='RSI')
ax.fill_between(data.index, y1=30, y2=70, color = 'lightcoral', alpha=0.3)
ax.set_xlabel('Date')
ax.set_ylabel('RSI')
plt.show()

# %% [markdown]
# ## OBV (On Balance Volume)

# %%
# OBV
data['OBV'] = ta.OBV(data['Adj Close'], data['Volume'])/10**6

data['Adj Close'].plot()
plt.ylabel('Close')
plt.show()

data.OBV.plot()
plt.ylabel('On Balance Volume (in millions)')
plt.show()
