# %%
# !pip install yfinance --quiet
# Out:
#      |████████████████████████████████| 62 kB 1.2 MB/s

# %% [markdown]
# # Big Three Trading Strategy

# %% [markdown]
# 20 Period Simple Moving Average
#
# 40 Period Simple Moving Average
#
# 80 Period Simple Moving Average
#
#
# https://tradingstrategyguides.com/big-three-trading-strategy/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# fix_yahoo_finance is used to fetch data 
import yfinance as yf
yf.pdr_override()

# %%
# input
symbol = 'TCS.NS'
start = '2014-01-01'
end = '2018-12-31'

# Read data 
df = yf.download(symbol,start,end)

# View Columns
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close   Adj Close  \
# Date
# 2014-01-01  1090.050049  1092.250000  1075.550049  1076.650024  904.462646
# 2014-01-02  1083.000000  1094.500000  1078.074951  1083.500000  910.217102
# 2014-01-03  1082.349976  1114.550049  1073.625000  1111.099976  933.403259
# 2014-01-06  1114.500000  1122.000000  1098.500000  1119.800049  940.711487
# 2014-01-07  1120.000000  1128.224976  1099.500000  1103.074951  926.661499
#
#              Volume
# Date
# 2014-01-01   529952
# 2014-01-02  1726948
# 2014-01-03  2618174
# 2014-01-06  2311810
# 2014-01-07  2897486

# %%
df['SMA_20'] = df['Adj Close'].rolling(20).mean()
df['SMA_40'] = df['Adj Close'].rolling(40).mean()
df['SMA_80'] = df['Adj Close'].rolling(80).mean()

# %%
df.tail()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2018-12-21  1948.000000  1950.000000  1886.550049  1895.800049  1761.922485
# 2018-12-24  1905.800049  1938.900024  1905.000000  1918.500000  1783.019287
# 2018-12-26  1921.800049  1921.800049  1870.250000  1889.199951  1755.788574
# 2018-12-27  1909.000000  1941.699951  1872.099976  1908.949951  1774.143555
# 2018-12-28  1915.000000  1920.000000  1893.000000  1896.050049  1762.154907
#
#              Volume       SMA_20       SMA_40       SMA_80
# Date
# 2018-12-21  3729956  1830.991681  1793.187885  1850.629471
# 2018-12-24  1864116  1834.356049  1794.709744  1849.233009
# 2018-12-26  2446614  1834.307263  1796.803183  1847.404579
# 2018-12-27  4968201  1830.824402  1797.684930  1845.593437
# 2018-12-28  2239130  1827.827155  1797.713974  1843.599979

# %%
fig, ax = plt.subplots(figsize=(16,9))

ax.plot(df.index, df['Adj Close'], label='Price')
ax.plot(df.index, df['SMA_20'], label = '20-days SMA')
ax.plot(df.index, df['SMA_40'], label = '40-days SMA')
ax.plot(df.index, df['SMA_80'], label = '80-days SMA')

ax.legend(loc='best')
ax.set_ylabel('Price')
ax.set_title('Big Three Trading Strategy')
# Out:
# Text(0.5, 1.0, 'Big Three Trading Strategy')

# %% [markdown]
# ## Closer View
#
# plot different dates

# %%
new_dates = df['2017-01-01':'2018-12-31']
new_dates.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2017-01-02  1183.300049  1187.550049  1176.199951  1180.675049  1060.329712
# 2017-01-03  1180.625000  1185.849976  1171.650024  1184.125000  1063.428101
# 2017-01-04  1184.849976  1194.425049  1179.150024  1189.750000  1068.479980
# 2017-01-05  1192.000000  1194.974976  1160.199951  1167.199951  1048.228394
# 2017-01-06  1160.500000  1164.675049  1128.550049  1140.699951  1024.429688
#
#              Volume       SMA_20       SMA_40       SMA_80
# Date
# 2017-01-02   823132  1020.030029  1003.535847  1036.564297
# 2017-01-03  1475324  1024.203809  1004.559644  1035.951633
# 2017-01-04  1420066  1029.254333  1005.640701  1035.645632
# 2017-01-05  2216404  1032.367261  1007.487924  1035.749554
# 2017-01-06  3009896  1034.301492  1008.901831  1035.386100

# %%
plt.figure(figsize=(16,10))
plt.plot(new_dates['Adj Close'], label='Price')
plt.plot(new_dates['SMA_20'], label = '20-days SMA')
plt.plot(new_dates['SMA_40'], label = '40-days SMA')
plt.plot(new_dates['SMA_80'], label = '80-days SMA')
plt.legend(loc='best')
plt.grid(True)
plt.ylabel('Price')
plt.xlabel('Dates')
plt.title('Big Three Trading Strategy')
# Out:
# Text(0.5, 1.0, 'Big Three Trading Strategy')

# %%
plt.figure(figsize=(16,10))
plt.plot_date(x=new_dates.index ,y=new_dates['Adj Close'], label='Price')
plt.plot(new_dates['SMA_20'], label = '20-days SMA')
plt.plot(new_dates['SMA_40'], label = '40-days SMA')
plt.plot(new_dates['SMA_80'], label = '80-days SMA')
plt.legend(loc='best')
plt.grid(True)
plt.ylabel('Price')
plt.xlabel('Dates')
plt.title('Big Three Trading Strategy')
# Out:
# Text(0.5, 1.0, 'Big Three Trading Strategy')

# %%
plt.figure(figsize=(16,10))
plt.plot_date(x=new_dates.index ,y=new_dates['Adj Close'], fmt='r-', label='Price')
plt.plot(new_dates['SMA_20'], label = '20-days SMA', color='b')
plt.plot(new_dates['SMA_40'], label = '40-days SMA', color='y')
plt.plot(new_dates['SMA_80'], label = '80-days SMA', color='green')
plt.legend(loc='best')
plt.grid(True)
plt.ylabel('Price')
plt.xlabel('Date')
plt.title('Big Three Trading Strategy')
# Out:
# Text(0.5, 1.0, 'Big Three Trading Strategy')
