# %%
# !pip install yfinance --quiet
# Out:
#      |████████████████████████████████| 62 kB 572 kB/s

# %% [markdown]
# ### Predicting Market Direction
# ---

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import statsmodels.api as sm
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
sensex_data = yf.download("^BSESN", start='2001-01-03', end='2005-12-31')
sensex_data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2001-01-03  3977.580078  4067.659912  3977.580078  4060.020020  4060.020020
# 2001-01-04  4180.970215  4180.970215  4109.549805  4115.370117  4115.370117
# 2001-01-05  4116.339844  4195.009766  4115.350098  4183.729980  4183.729980
# 2001-01-08  4164.759766  4206.720215  4101.529785  4120.430176  4120.430176
# 2001-01-09  4114.740234  4166.839844  4101.009766  4125.310059  4125.310059
# ...                 ...          ...          ...          ...          ...
# 2005-12-26  9254.089844  9262.480469  9050.509766  9085.889648  9085.889648
# 2005-12-27  9071.250000  9297.070312  9020.799805  9283.160156  9283.160156
# 2005-12-28  9292.179688  9350.820312  9207.269531  9257.509766  9257.509766
# 2005-12-29  9272.629883  9338.110352  9271.629883  9323.250000  9323.250000
# 2005-12-30  9339.320312  9427.230469  9311.530273  9397.929688  9397.929688
#
#             Volume
# Date
# 2001-01-03       0
# 2001-01-04       0
# 2001-01-05       0
# 2001-01-08       0
# 2001-01-09       0
# ...            ...
# 2005-12-26   15400
# 2005-12-27   14600
# 2005-12-28   19600
# 2005-12-29   14200
# 2005-12-30   15200
#
# [1245 rows x 6 columns]

# %%
# Calculate daily returns data
df = sensex_data['Adj Close'].pct_change()*100
df
# Out:
# Date
# 2001-01-03         NaN
# 2001-01-04    1.363296
# 2001-01-05    1.661087
# 2001-01-08   -1.512999
# 2001-01-09    0.118431
#                 ...
# 2005-12-26   -1.847490
# 2005-12-27    2.171174
# 2005-12-28   -0.276311
# 2005-12-29    0.710129
# 2005-12-30    0.801005
# Name: Adj Close, Length: 1245, dtype: float64

# %%
df = df.rename("Today").reset_index()
df
# Out:
#            Date     Today
# 0    2001-01-03       NaN
# 1    2001-01-04  1.363296
# 2    2001-01-05  1.661087
# 3    2001-01-08 -1.512999
# 4    2001-01-09  0.118431
# ...         ...       ...
# 1240 2005-12-26 -1.847490
# 1241 2005-12-27  2.171174
# 1242 2005-12-28 -0.276311
# 1243 2005-12-29  0.710129
# 1244 2005-12-30  0.801005
#
# [1245 rows x 2 columns]

# %%
# Calculate the Lags
for i in range(1, 6):
    df['Lag_' + str(i)] = df['Today'].shift(i)

df
# Out:
#            Date     Today     Lag_1     Lag_2     Lag_3     Lag_4     Lag_5
# 0    2001-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 1    2001-01-04  1.363296       NaN       NaN       NaN       NaN       NaN
# 2    2001-01-05  1.661087  1.363296       NaN       NaN       NaN       NaN
# 3    2001-01-08 -1.512999  1.661087  1.363296       NaN       NaN       NaN
# 4    2001-01-09  0.118431 -1.512999  1.661087  1.363296       NaN       NaN
# ...         ...       ...       ...       ...       ...       ...       ...
# 1240 2005-12-26 -1.847490 -1.231178  0.354741 -0.075649 -0.511262  1.182724
# 1241 2005-12-27  2.171174 -1.847490 -1.231178  0.354741 -0.075649 -0.511262
# 1242 2005-12-28 -0.276311  2.171174 -1.847490 -1.231178  0.354741 -0.075649
# 1243 2005-12-29  0.710129 -0.276311  2.171174 -1.847490 -1.231178  0.354741
# 1244 2005-12-30  0.801005  0.710129 -0.276311  2.171174 -1.847490 -1.231178
#
# [1245 rows x 7 columns]

# %%
# Lets get the volume of the prior day
# Divide by 1,000,000,000 to scale
df['Volume'] = sp500_data.Volume.shift(1).values/1000000000

# %%
df = df.dropna()
df
# Out:
#            Date     Today     Lag_1     Lag_2     Lag_3     Lag_4     Lag_5  \
# 6    2001-01-11 -0.506715 -1.882772  0.118431 -1.512999  1.661087  1.363296
# 7    2001-01-12  0.234663 -0.506715 -1.882772  0.118431 -1.512999  1.661087
# 8    2001-01-15  0.252192  0.234663 -0.506715 -1.882772  0.118431 -1.512999
# 9    2001-01-16  0.592325  0.252192  0.234663 -0.506715 -1.882772  0.118431
# 10   2001-01-17  0.311490  0.592325  0.252192  0.234663 -0.506715 -1.882772
# ...         ...       ...       ...       ...       ...       ...       ...
# 1240 2005-12-26 -1.847490 -1.231178  0.354741 -0.075649 -0.511262  1.182724
# 1241 2005-12-27  2.171174 -1.847490 -1.231178  0.354741 -0.075649 -0.511262
# 1242 2005-12-28 -0.276311  2.171174 -1.847490 -1.231178  0.354741 -0.075649
# 1243 2005-12-29  0.710129 -0.276311  2.171174 -1.847490 -1.231178  0.354741
# 1244 2005-12-30  0.801005  0.710129 -0.276311  2.171174 -1.847490 -1.231178
#
#         Volume
# 6     0.000000
# 7     0.000000
# 8     0.000000
# 9     0.000000
# 10    0.000000
# ...        ...
# 1240  0.000016
# 1241  0.000015
# 1242  0.000015
# 1243  0.000020
# 1244  0.000014
#
# [1239 rows x 8 columns]

# %%
# Now add in the direction
# 1 for up and 0 for down
df['Direction'] = [1 if i > 0 else 0 for i in df['Today']]
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#            Date     Today     Lag_1     Lag_2     Lag_3     Lag_4     Lag_5  \
# 6    2001-01-11 -0.506715 -1.882772  0.118431 -1.512999  1.661087  1.363296
# 7    2001-01-12  0.234663 -0.506715 -1.882772  0.118431 -1.512999  1.661087
# 8    2001-01-15  0.252192  0.234663 -0.506715 -1.882772  0.118431 -1.512999
# 9    2001-01-16  0.592325  0.252192  0.234663 -0.506715 -1.882772  0.118431
# 10   2001-01-17  0.311490  0.592325  0.252192  0.234663 -0.506715 -1.882772
# ...         ...       ...       ...       ...       ...       ...       ...
# 1240 2005-12-26 -1.847490 -1.231178  0.354741 -0.075649 -0.511262  1.182724
# 1241 2005-12-27  2.171174 -1.847490 -1.231178  0.354741 -0.075649 -0.511262
# 1242 2005-12-28 -0.276311  2.171174 -1.847490 -1.231178  0.354741 -0.075649
# 1243 2005-12-29  0.710129 -0.276311  2.171174 -1.847490 -1.231178  0.354741
# 1244 2005-12-30  0.801005  0.710129 -0.276311  2.171174 -1.847490 -1.231178
#
#         Volume  Direction
# 6     0.000000          0
# 7     0.000000          1
# 8     0.000000          1
# 9     0.000000          1
# 10    0.000000          1
# ...        ...        ...
# 1240  0.000016          0
# 1241  0.000015          1
# 1242  0.000015          0
# 1243  0.000020          1
# 1244  0.000014          1
#
# [1239 rows x 9 columns]

# %%
# Add a constant so that sm_api provides an intercept
df = sm.add_constant(df)
df
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:117: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
#       const       Date     Today     Lag_1     Lag_2     Lag_3     Lag_4  \
# 6       1.0 2001-01-11 -0.506715 -1.882772  0.118431 -1.512999  1.661087
# 7       1.0 2001-01-12  0.234663 -0.506715 -1.882772  0.118431 -1.512999
# 8       1.0 2001-01-15  0.252192  0.234663 -0.506715 -1.882772  0.118431
# 9       1.0 2001-01-16  0.592325  0.252192  0.234663 -0.506715 -1.882772
# 10      1.0 2001-01-17  0.311490  0.592325  0.252192  0.234663 -0.506715
# ...     ...        ...       ...       ...       ...       ...       ...
# 1240    1.0 2005-12-26 -1.847490 -1.231178  0.354741 -0.075649 -0.511262
# 1241    1.0 2005-12-27  2.171174 -1.847490 -1.231178  0.354741 -0.075649
# 1242    1.0 2005-12-28 -0.276311  2.171174 -1.847490 -1.231178  0.354741
# 1243    1.0 2005-12-29  0.710129 -0.276311  2.171174 -1.847490 -1.231178
# 1244    1.0 2005-12-30  0.801005  0.710129 -0.276311  2.171174 -1.847490
#
#          Lag_5    Volume  Direction
# 6     1.363296  0.000000          0
# 7     1.661087  0.000000          1
# 8    -1.512999  0.000000          1
# 9     0.118431  0.000000          1
# 10   -1.882772  0.000000          1
# ...        ...       ...        ...
# 1240  1.182724  0.000016          0
# 1241 -0.511262  0.000015          1
# 1242 -0.075649  0.000015          0
# 1243  0.354741  0.000020          1
# 1244 -1.231178  0.000014          1
#
# [1239 rows x 10 columns]

# %%
# Independent vars
X = df[['const', 'Lag_1','Lag_2','Lag_3','Lag_4','Lag_5','Volume']]

# %%
# Dependent variable is market diretion
y = df.Direction

# %%
y
# Out:
# 6       0
# 7       1
# 8       1
# 9       1
# 10      1
#        ..
# 1240    0
# 1241    1
# 1242    0
# 1243    1
# 1244    1
# Name: Direction, Length: 1239, dtype: int64

# %%
# Define a Logit model
model = sm.Logit(y, X)
# Fit the model
result = model.fit()
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 10.380282
#          Iterations: 35
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              Direction   No. Observations:                 1239
# Model:                          Logit   Df Residuals:                     1232
# Method:                           MLE   Df Model:                            6
# Date:                Sat, 06 Aug 2022   Pseudo R-squ.:                  -14.08
# Time:                        15:33:29   Log-Likelihood:                -12861.
# converged:                      False   LL-Null:                       -853.09
# Covariance Type:            nonrobust   LLR p-value:                     1.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         17.9823      2.664      6.750      0.000      12.761      23.204
# Lag_1          5.9353      0.936      6.338      0.000       4.100       7.771
# Lag_2          0.3401      0.225      1.513      0.130      -0.101       0.781
# Lag_3          3.2967      0.518      6.361      0.000       2.281       4.313
# Lag_4          4.5717      0.716      6.389      0.000       3.169       5.974
# Lag_5          0.9593      0.195      4.924      0.000       0.577       1.341
# Volume     -1.782e+06   2.69e+05     -6.623      0.000   -2.31e+06   -1.25e+06
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.39 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
# """

# %% [markdown]
# None of the Lags are statistically significant as per p-values

# %%
# Predict if the market is going up or down
mkt_dir_prediction = result.predict(X)

# %%
mkt_dir_prediction
# Out:
# 6       9.999788e-01
# 7       9.999174e-01
# 8       9.999944e-01
# 9       9.999168e-01
# 10      1.000000e+00
#             ...
# 1240    6.708951e-09
# 1241    1.226732e-09
# 1242    8.464188e-01
# 1243    2.011023e-13
# 1244    3.410503e-03
# Length: 1239, dtype: float64

# %%
# Did our model perform well?
def confusion_matrix(act, pred):
    # In Logistic regresion a prediction > 0.5 is rounded up to 1
    # predicted_values_transform = ['Up' if i > 0.5 else 'Down' for i in pred]
    # actual_values = ['Up' if i > 0 else 'Down' for i in act]
    predicted_values_transform = np.where(pred > 0.5, 'Up', 'Down')
    actual_values = np.where(act > 0, 'Up', 'Down')
    # Convert dataframe to series for this to work
    confusion_matrix = pd.crosstab(pd.Series(actual_values.squeeze()), 
                                    pd.Series(predicted_values_transform.squeeze()),
                                    rownames=['Actual'],
                                    colnames=['Predicted'])
    return confusion_matrix

# %%
y.ndim
# Out:
# 1

# %%
mkt_dir_prediction.ndim
# Out:
# 1

# %%
confusion_matrix(y, mkt_dir_prediction)
# Out:
# Predicted  Down   Up
# Actual
# Down        242  318
# Up          316  363

# %%
len(df)
# Out:
# 1239

# %%
# Cprrect prediction divided by total number of observations
(155+504)/1250
# Out:
# 0.5272

# %% [markdown]
# While it seems as though we are doing better than a coin toss, we are training and testing the model on the same data!
#
#
# #### Split into Train and test datasets
#
# Train data pre-2005. Test data in 2005

# %%
X_train = df[df.Date.dt.year < 2005][['const', 'Lag_1','Lag_2','Lag_3','Lag_4','Lag_5','Volume']]
y_train = df[df.Date.dt.year < 2005][['Direction']]
X_test = df[df.Date.dt.year == 2005][['const', 'Lag_1','Lag_2','Lag_3','Lag_4','Lag_5','Volume']]
y_test = df[df.Date.dt.year == 2005][['Direction']]

# %%
y_test
# Out:
#       Direction
# 997           1
# 998           0
# 999           0
# 1000          0
# 1001          1
# ...         ...
# 1240          0
# 1241          1
# 1242          0
# 1243          1
# 1244          1
#
# [248 rows x 1 columns]

# %%
model = sm.Logit(y_train, X_train)

# %%
result = model.fit()
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 12.260159
#          Iterations: 35
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %%
prediction = result.predict(X_test).to_frame()
prediction
# Out:
#                  0
# 997   1.791763e-08
# 998   5.118998e-09
# 999   1.069304e-13
# 1000  1.810188e-20
# 1001  1.588592e-18
# ...            ...
# 1240  8.715514e-14
# 1241  1.744850e-13
# 1242  1.039613e-10
# 1243  1.255850e-17
# 1244  2.348943e-11
#
# [248 rows x 1 columns]

# %%
print(y_test.ndim)
print(prediction.ndim)
# Out:
# 2
# 2

# %%
print(y_test.squeeze().ndim)
print(prediction.squeeze().ndim)
# Out:
# 1
# 1

# %%
confusion_matrix(y_test, prediction)
# Out:
# Predicted  Down  Up
# Actual
# Down        107   0
# Up          140   1

# %%
# How does this perform?
(81+38)/len(X_test)
# Out:
# 0.4798387096774194

# %%
# What happens if you drop less relevant variables?
X_train = df[df.Date.dt.year < 2005][['const', 'Lag_1','Lag_2']]
y_train = df[df.Date.dt.year < 2005][['Direction']]
X_test = df[df.Date.dt.year == 2005][['const', 'Lag_1','Lag_2']]
y_test = df[df.Date.dt.year == 2005][['Direction']]

# %%
model = sm.Logit(y_train, X_train)
result = model.fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.684076
#          Iterations 4

# %%
prediction = result.predict(X_test)

# %%
confusion_matrix(y_test, prediction)
# Out:
# Predicted  Down   Up
# Actual
# Down         16   91
# Up           15  126

# %%
(40 + 104)/len(X_test)
# Out:
# 0.5806451612903226

# %% [markdown]
# #### We do better off by only taking the returns on the previous two days!
